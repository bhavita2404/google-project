# %%
import gmplot
import pandas as pd

lat_long_data = pd.read_csv('C:\\Users\\S\\OneDrive\\Desktop\\lat_long.txt', sep='|') # coverting a file to dataframe for easy extraction of data
    
lat_long_data['lat'] = lat_long_data['lat'].astype(float) 
lat_long_data['lng'] = lat_long_data['lng'].astype(float)
    
latitudes = lat_long_data['lat'].tolist()  
longitudes = lat_long_data['lng'].tolist() ## storing latitudes and longitudes of given locations in two seperate lists for easy plotting

mid_lat = (min(latitudes) + max(latitudes))/2
mid_lon = (min(longitudes) + max(longitudes))/2

gmap1 = gmplot.GoogleMapPlotter(mid_lat, mid_lon, size = 10 ) # GoogleMapPlotter requires info about centre of an area to be mapped and zoom-in value
gmap1.scatter(latitudes,longitudes,'white',size = 100, marker = False) ## scatter plot of all the given locations
gmap1.draw("C:\\Users\\S\\OneDrive\\Desktop\\map1.html")

# %%
left_dataframe = pd.read_csv('C:\\Users\\S\\Downloads\\mumbai_train_route.txt', sep='|')
right_dataframe = data    ## converting text files to dataframes
right_dataframe = right_dataframe.rename(columns = {"station_code": "src_station"}) # need a same coloumn name for merging thus renamed

a =pd.merge(left_dataframe, right_dataframe, on="src_station", how="left") # for identifying latitude and longitude of the corresponding stations in route, used left outer join to merge the two text files
a.to_csv('C:\\Users\\S\\Desktop\\mumbai_train_route_coord.txt', header=True, index=False, sep='\t', mode='w') # export dataframes to a file

# %%
file3 = open('C:\\Users\\S\\OneDrive\\Desktop\\mumbai_train_route_coord.txt',"r")
file4 = open('C:\\Users\\S\\OneDrive\\Desktop\\mumbai_seperated_train_route_coord.txt',"a") ## to store the distinct routes 
count = 0
start_dest = []
location_names = []
blue_route,red_route,green_route,violet_route= ['CCG','DRD'] , [['CSMT','KHPI'],['CSMT','KSRA']] , [['CSMT','GMN'],['CSMT','PNVL']] , [['TNA','VSH'],['PNVL','TNA']]  ## storing the endpoints of the coloured routes from mi-Indicator map
lines = ""
next(file3)
flag = 0
name = ""
train_no = 1
for line in file3:  
    x = int(line.split('\t')[0])
    prev_name = name
    name = line.split('\t')[1]
    seq = int(line.split('\t')[2])
    if count == 0:
        count+=1
        train_no = int(x)
        flag = 1
        start_dest.append([])
        start_dest[0].append(name)
        lines+= line
    else:
        if x == train_no:
            lines+= line
        else:
            train_no = int(x)
            count+=1
            if flag == 1:
                start_dest[0].append(prev_name)
                flag = 0
                file4.write(lines)
            else:
                location_names.append(prev_name)
                check = 0
                #print(location_names)
                for i in range(0,len(start_dest)):
                    start_dest[i].sort()
                    location_names.sort()
                    if start_dest[i] == location_names :
                        check = 1
                        break;      
                if check == 0:
                    start_dest.append(location_names)
                    if location_names == blue_route:
                        file4.write("blue \n")
                        file4.write(lines)
                        file4.write("blue \n")
                    elif location_names == red_route[0] or location_names == red_route[1]:
                        file4.write("red \n")
                        file4.write(lines)
                        file4.write("red \n")
                    elif location_names == violet_route[0] or location_names == violet_route[1]:
                        file4.write("violet \n")
                        file4.write(lines)
                        file4.write("violet \n")
                    elif location_names == green_route[0] or location_names == green_route[1]:
                        file4.write("green \n")
                        file4.write(lines)
                        file4.write("green \n")
                    else:
                        file4.write(lines)  
                        
                location_names = []    
            location_names.append(name)
            lines = ""
            lines+= line

file4.close()
print(count)
print(start_dest)
# Out:
# 3105
# ...

# %%
file1 = open('C:\\Users\\S\\OneDrive\\Desktop\\mumbai_seperated_train_route_coord.txt', "r")
route_lat,route_lon = [],[]
count = 0
for line in file1:
    if line.split(' ')[0] =="blue":
        count+=1
        print(count)
        if count == 2:
            break
    elif count == 1:    
        try:
            route_lat.append(float(line.split('\t')[10]))
            route_lon.append(float(line.split('\t')[11][:-1]))
        except:
            if line.split('\t')[10] == ' ' or line.split('\t')[11][:-1] == ' ' :
                continue #only for spaces
        
# finding the lat and long for the stations of a specific route and plotting(along the route) them on map

gmap1 = gmplot.GoogleMapPlotter(mid_lat, mid_lon, 10 )
gmap1.scatter(latitudes,longitudes,'white',size = 100, marker = False) ## scatter plot
gmap1.plot(route_lat, route_lon, 'blue', edge_width = 2.5)
print(route_lat,route_lon)
gmap1.draw( "C:\\Users\\S\\OneDrive\\Desktop\\map11.html" )
# Out:
# 1
# 2
# [18.93449, 18.94566, 18.95139, 18.9635, 18.97084, 18.982001, 18.995279999999998, 19.007445, 19.01888, 19.02816, 19.040670000000002, 19.05474, 19.0696, 19.08156, 19.10004, 19.11874, 19.136470000000003, 19.15168, 19.16461, 19.18723, 19.20451, 19.21089, 19.22891, 19.25007, 19.27972, 19.31093, 19.351470000000003, 19.38275, 19.4174, 19.434821, 19.454952, 19.5179, 19.5767, 19.6246, 19.6981, 19.7544, 19.7983, 19.883, 19.9913] [72.82729, 72.82378, 72.81891, 72.8161, 72.81886, 72.824187, 72.83015, 72.835898, 72.84299, 72.84699, 72.84671999999999, 72.84040999999999, 72.84023, 72.84164, 72.84406, 72.84692, 72.84895999999999, 72.85023000000001, 72.84961, 72.84898000000001, 72.85199, 72.85321, 72.85673, 72.85916999999999, 72.85611999999999, 72.8526, 72.84621, 72.83189, 72.819, 72.815792, 72.812027, 72.8502, 72.8219, 72.7911, 72.77209, 72.7604, 72.7616, 72.7633, 72.7436]

# %%
gmap1 = gmplot.GoogleMapPlotter(mid_lat, mid_lon, 10 )
file1 = open('C:\\Users\\S\\OneDrive\\Desktop\\mumbai_seperated_train_route_coord.txt', "r")
route_lat,route_lon = [],[]
blue_count,red_count,violet_count,green_count = 0,0,0,0
for line in file1:
    if line.split(' ')[0] =="blue":
        blue_count+=1
        print('go')
        if blue_count == 2:
            gmap1.plot(route_lat, route_lon, 'blue', edge_width = 2.5)
            route_lat,route_lon = [],[]
    elif blue_count == 1:    
        try:
            route_lat.append(float(line.split('\t')[10]))
            route_lon.append(float(line.split('\t')[11][:-1]))
        except:
            if line.split('\t')[10] == ' ' or line.split('\t')[11][:-1] == ' ' :
                continue #only for spaces
                
    if line.split(' ')[0] =="red":
        red_count+=1
        
        if red_count == 2:
            gmap1.plot(route_lat, route_lon, 'red', edge_width = 2.5)
            route_lat,route_lon = [],[]
            red_count = 0
    elif red_count == 1:    
        try:
            route_lat.append(float(line.split('\t')[10]))
            route_lon.append(float(line.split('\t')[11][:-1]))
        except:
            if line.split('\t')[10] == ' ' or line.split('\t')[11][:-1] == ' ' :
                continue #only for spaces
                
    if line.split(' ')[0] =="green":
        green_count+=1
       
        if green_count == 2:
            gmap1.plot(route_lat, route_lon, 'green', edge_width = 2.5)
            route_lat,route_lon = [],[]
            green_count = 0
    elif green_count == 1:    
        try:
            route_lat.append(float(line.split('\t')[10]))
            route_lon.append(float(line.split('\t')[11][:-1]))
        except:
            if line.split('\t')[10] == ' ' or line.split('\t')[11][:-1] == ' ' :
                continue #only for spaces
                
    if line.split(' ')[0] =="violet":
        violet_count+=1
        
        if violet_count == 2:
            gmap1.plot(route_lat, route_lon, 'violet', edge_width = 2.5)
            route_lat,route_lon = [],[]
            violet_count = 0
    elif violet_count == 1:    
        try:
            route_lat.append(float(line.split('\t')[10]))
            route_lon.append(float(line.split('\t')[11][:-1]))
        except:
            if line.split('\t')[10] == ' ' or line.split('\t')[11][:-1] == ' ' :
                continue #only for spaces            
        
# finding the lat and long for the stations of a specific route and plotting(along the route) them on map


gmap1.scatter(latitudes,longitudes,'white',size = 100, marker = False) ## scatter plot
gmap1.draw( "C:\\Users\\S\\OneDrive\\Desktop\\map12.html" )
# Out:
# go
# go

# %%
## adding the station names ( will appear only on hovering the mouse )
lat_long_data = pd.read_csv('C:\\Users\\S\\OneDrive\\Desktop\\lat_long.txt', sep='|') # coverting a file to dataframe for easy extraction of data
    
lat_long_data['lat'] = lat_long_data['lat'].astype(float)
lat_long_data['lng'] = lat_long_data['lng'].astype(float)
    
latitudes = lat_long_data['lat'].tolist()  
longitudes = lat_long_data['lng'].tolist() ## storing latitudes and longitudes of locations in two seperate lists for easy plotting
name = lat_long_data['station_name'].tolist()

for i in range(len(latitudes)):
    gmap1.marker(latitudes[i],longitudes[i],title = name[i])
gmap1.draw( "C:\\Users\\S\\Desktop\\map2.html")

# %%
# To join the points on map with the best fit line (using Linear Regression)

import numpy as np 
import matplotlib.pyplot as plt
import gmplot
  
def estimate_coef(x, y): 
    # number of points 
    n = np.size(x) 
  
    # mean of x and y array
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b1 = SS_xy / SS_xx 
    b0 = m_y - b1*m_x 
  
    return(b0, b1)  


def plot_regreesion_route(lat,lon,gmap1,pcolor):
    
    x = np.array(lat)
    # estimating coefficients 
    b = estimate_coef(x, np.array(lon)) 
    #print(b[0],b[1])
    
    # plotting regression line 
    y_pred = b[0] + b[1]*x
    
    gmap1.scatter(lat,lon,'white',size = 100, marker = False)
    #gmap1.apikey = "AIzaSyAbr98I2YDjSiJR5Sv81zkfrB5uNAhCuMU"
    gmap1.plot(x,y_pred,pcolor,edge_width=2.5)
    

def main():

    gmap1 = gmplot.GoogleMapPlotter(18.77778,73.31833, 10 ) 
    
    file3 = open('C:\\Users\\S\\Desktop\\local_train_route_coord.txt',"r")
    route_lat,route_lon = [],[]
    count = 0
    route = 1
    color = ""
    for line in file3:
        if count == 0:
            count+=1
            continue;  
        x = int(line.split('\t')[13])
        if count == 1:
            route = int(x)
            color = line.split('\t')[12]
            try:
                route_lat.append(float(line.split('\t')[10]))
                route_lon.append(float(line.split('\t')[11][:-1]))
            except:
                continue #only for spaces
        else:
            if x == route:
                try:
                    route_lat.append(float(line.split('\t')[10]))
                    route_lon.append(float(line.split('\t')[11][:-1]))
                except:
                    continue #only for spaces
            else:
                route = int(x)
                pcolor = color 
                color = line.split('\t')[12]
                print(pcolor)
                
                plot_regreesion_route(route_lat,route_lon,gmap1,pcolor)
                route_lat,route_lon = [],[]
                try:
                    route_lat.append(float(line.split('\t')[10]))
                    route_lon.append(float(line.split('\t')[11][:-1]))
                except:
                    continue #only for spaces
        count+=1  

    plot_regreesion_route(route_lat,route_lon,gmap1,pcolor)
    gmap1.draw( "C:\\Users\\S\\Desktop\\Linear-regression.html")
    
if __name__ == "__main__": 
    main()

# %%
# for obtaining only blue route in the map

import numpy as np 
import matplotlib.pyplot as plt
import gmplot
  
def estimate_coef(x1, y1):
    x = np.array(x1)
    y = np.array(y1)
    
    # number of points 
    n = np.size(x) 
  
    # mean of x and y array
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b1 = SS_xy / SS_xx 
    b0 = m_y - b1*m_x 
  
    return(b0, b1)  


def plot_regression_route(lat,lon,gmap1,pcolor,name):

    # estimating coefficients 
    b = estimate_coef(lat,lon) 
    #print(b[0],b[1])
    
    # plotting regression line 
    y_pred = b[0] + b[1]*np.array(lat)
    
    gmap1.scatter(lat,lon,'white',size = 100, marker = False)
    gmap1.plot(lat,y_pred,pcolor,edge_width=2.5)
    

def main():

    gmap1 = gmplot.GoogleMapPlotter(18.77778,73.31833, 10 ) 
    
    file3 = open('C:\\Users\\S\\Desktop\\local_train_route_coord.txt',"r")
    route_lat,route_lon,name = [],[],[]
    count = 0
    for line in file3:
        if count == 0:
            count+=1
            continue;  
        color = line.split('\t')[12]
        if color == "blue":
            try:
                route_lat.append(float(line.split('\t')[10]))
                route_lon.append(float(line.split('\t')[11][:-1]))
                name.append((line.split('\t')[9]))
            except:
                continue #only for spaces
        count+=1  
    
    plot_regression_route(route_lat,route_lon,gmap1,"blue",name)
    gmap1.draw( "C:\\Users\\S\\Desktop\\LR(blue-route).html")
    
if __name__ == "__main__": 
    main()




# breaking the route line to decrease the total error

import numpy as np 
import matplotlib.pyplot as plt
import gmplot
  
def estimate_coef(x1, y1):
    x = np.array(x1)
    y = np.array(y1)
    
    # number of points 
    n = np.size(x) 
  
    # mean of x and y array
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b1 = SS_xy / SS_xx 
    b0 = m_y - b1*m_x 
  
    return(b0, b1)  


def plot_regression_route(lat,lon,gmap1,pcolor,name):

    # estimating coefficients 
    b = estimate_coef(lat,lon) 
    #print(b[0],b[1])
    
    # plotting regression line 
    y_pred = b[0] + b[1]*np.array(lat)
    
    neg = 0
    x1,y1,x2,y2=[],[],[],[]
    for i in range(len(lon)):
        if lon[i] - y_pred[i] < 0:
            neg+=1
            x1.append(lat[i])
            y1.append(lon[i])
        else:
            if neg >= 4:
                b1 = estimate_coef(x1,y1)
                y_pred1 = b1[0] + ( b1[1]* np.array(x1) )
                gmap1.plot(x1,y_pred1,pcolor,edge_width=2.5)
            if neg > 0:
                x1,y1=[],[]
                neg = 0
            x2.append(lat[i])
            y2.append(lon[i])
        print(name[i],(lon[i]-y_pred[i]))
    
    b2 = estimate_coef(x2,y2)
    y_pred2 = b2[0] + b2[1]*np.array(x2)
    
    if len(x1) > 0 :
        b1 = estimate_coef(x1,y1)
        y_pred1 = b1[0] + ( b1[1]* np.array(x1) )
        gmap1.plot(x1,y_pred1,pcolor,edge_width=2.5)
        
    #gmap1.apikey = "AIzaSyAbr98I2YDjSiJR5Sv81zkfrB5uNAhCuMU"
    gmap1.plot(x2,y_pred2,pcolor,edge_width=2.5)
    

def main():

    gmap1 = gmplot.GoogleMapPlotter(18.77778,73.31833, 10 ) 
    
    file3 = open('C:\\Users\\S\\Desktop\\local_train_route_coord.txt',"r")
    route_lat,route_lon,name = [],[],[]
    count = 0
    for line in file3:
        if count == 0:
            count+=1
            continue;  
        color = line.split('\t')[12]
        if color == "blue":
            try:
                route_lat.append(float(line.split('\t')[10]))
                route_lon.append(float(line.split('\t')[11][:-1]))
                name.append((line.split('\t')[9]))
            except:
                continue #only for spaces
        count+=1  
    gmap1.scatter(route_lat,route_lon,'white',size = 100, marker = False)
    plot_regression_route(route_lat,route_lon,gmap1,"blue",name)
    gmap1.draw( "C:\\Users\\S\\Desktop\\LR(improved).html")
    
if __name__ == "__main__": 
    main()


Output of the location and its corresponding error

Dahanu Road      -0.028079658303738597
Vangaon      -0.016381236594384063
Boisar      -0.02487379136094603
Umroli      -0.02923888172990985
Palghar      -0.0215544759844164
Kelve Road      -0.008188511112436458
Saphale      0.018139784361963507
Vaitarna      0.04263255625956219
Virar      -0.00017263072325590656
Virar Carshed      0.0020542568799868377
Nalla Sopara      -0.005071124425654716
Vasai Road      0.014072830442572126
Naigaon      0.026075107737739245
Bhayandar      0.028767573260353174
Mira Road      0.030495216303165762
Dahisar      0.03127243886717679
Borivali      0.02718044997872937
Kandivli EMU Shed      0.02229915320312159
Kandivli      0.02051010362330885
Malad      0.016265530466682776
Goregaon      0.015151627410958213
Ram Mandir      0.014790497149661519
Jogeshwari      0.012354596819008634
Andheri      0.008935529569853884
Ville Parle      0.004602108387615544
Santa Cruz      0.0007855509840055674
Khar Road      -0.0015312253443084956
Bandra      -0.002460296936263262
Mahim Junction      0.002771187767805827
Matunga Road      0.001992251993058858
Dadar Western      -0.0027190928503131317
Prabhadevi      -0.010605626070571361
Lower Parel      -0.017328116374415004
Mahalakshmi      -0.0242659987208782
Mumbai Central Local      -0.030501528871397454
Grant Road      -0.033864165848797256
Charni Road      -0.0318924402079972
Marine Lines      -0.02753166498735027
Church Gate      -0.024887885019737155



# breaking the route line to decrease the total error and improvised plot_regression_route function to include the last point of one line to another line as first point ( for a better view of a route)

import numpy as np 
import matplotlib.pyplot as plt
import gmplot
  
def estimate_coef(x1, y1):
    x = np.array(x1)
    y = np.array(y1)
    
    # number of points 
    n = np.size(x) 
  
    # mean of x and y array
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b1 = SS_xy / SS_xx 
    b0 = m_y - b1*m_x 
  
    return(b0, b1)  


def plot_regression_route(lat,lon,gmap1,pcolor,name):

    # estimating coefficients 
    b = estimate_coef(lat,lon) 
    #print(b[0],b[1])
    
    # plotting regression line 
    y_pred = b[0] + b[1]*np.array(lat)
    
    neg = 0
    x1,y1,x2,y2=[],[],[],[]
    for i in range(len(lon)):
        if lon[i] - y_pred[i] < 0:
            neg+=1
            x1.append(lat[i])
            y1.append(lon[i])
        else:
            if neg >= 4:
                x1.append(lat[i])
                y1.append(lon[i])
                b1 = estimate_coef(x1,y1)
                y_pred1 = b1[0] + ( b1[1]* np.array(x1) )
                gmap1.plot(x1,y_pred1,pcolor,edge_width=2.5)
                x1,y1=[],[]
                neg = 0
            elif neg > 0:
                x2 = x2 + x1
                y2 = y2 + y1
                x1,y1 = [],[]
                neg = 0
                
            x2.append(lat[i])
            y2.append(lon[i])
        print(name[i],(lon[i]-y_pred[i]))
    
    if neg >= 4 :
        x2.append(x1[0])
        y2.append(y1[0])
        b1 = estimate_coef(x1,y1)
        y_pred1 = b1[0] + ( b1[1]* np.array(x1) )
        gmap1.plot(x1,y_pred1,pcolor,edge_width=2.5)
    elif neg > 0 and neg < 4:
        x2 = x2 + x1
        y2 = y2 + y1
        
    b2 = estimate_coef(x2,y2)
    y_pred2 = b2[0] + ( b2[1]*np.array(x2))
    #gmap1.apikey = "AIzaSyAbr98I2YDjSiJR5Sv81zkfrB5uNAhCuMU"
    gmap1.plot(x2,y_pred2,pcolor,edge_width=2.5)
    

def main():

    gmap1 = gmplot.GoogleMapPlotter(18.77778,73.31833, 10 ) 
    
    file3 = open('C:\\Users\\S\\OneDrive\\Desktop\\local_train_route_coord.txt',"r")
    route_lat,route_lon,name = [],[],[]
    count = 0
    for line in file3:
        if count == 0:
            count+=1
            continue;  
        color = line.split('\t')[12]
        if color == "blue":
            try:
                route_lat.append(float(line.split('\t')[10]))
                route_lon.append(float(line.split('\t')[11][:-1]))
                name.append((line.split('\t')[9]))
            except:
                continue #only for spaces
        count+=1  
    gmap1.scatter(route_lat,route_lon,'white',size = 100, marker = False)
    plot_regression_route(route_lat,route_lon,gmap1,"blue",name)
    gmap1.draw( "C:\\Users\\S\\OneDrive\\Desktop\\LR(improved).html")
    
if __name__ == "__main__": 
    main()

# %%
import pandas as pd
import gmplot

# to insert the header row in the file ( for easy processing of data )
header = "station_code|station_name|popularity|lat|lon" + "\n"
f = open('C:\\Users\\S\\Downloads\\station_info_aggregated.txt', 'r') 
lines = f.readlines()
lines.insert(0,header)
f.close()
f = open('C:\\Users\\S\\Downloads\\station_info_aggregated.txt', 'w')
f.writelines(lines)
f.close()

# convert text file to dataframe form ( helps in easy extraction of latitudes and longitudes info )
data = pd.read_csv('C:\\Users\\S\\Downloads\\station_info_aggregated.txt', sep='|')
data['lat'] = data['lat'].astype(float)
data['lon'] = data['lon'].astype(float)

latitudes = data['lat'].tolist()
longitudes = data['lon'].tolist()
avg_lat = ((max(latitudes)) +  min(latitudes))/2        # finding minimum and maximum lat and long helps to finding midpoint 
avg_lon = (max(longitudes) +  min(longitudes))/2
print(avg_lat,avg_lon)




gmap1 = gmplot.GoogleMapPlotter(21.1458,79.0882, 5 ) 

# scatter plot to plot the stations all over India ( using given latitudes and longitudes)
gmap1.scatter(latitudes,longitudes,'white',size = 5, marker = False) 
gmap1.draw( "C:\\Users\\S\\OneDrive\\Desktop\\India_stations.html")









# left outer join to merge the files into one (using dataframes)
left_dataframe = pd.read_csv('C:\\Users\\S\\Downloads\\wimt_full_route_map.txt', sep='|')
right_dataframe = pd.read_csv('C:\\Users\\S\\Downloads\\station_info_aggregated.txt', sep='|')
##  converting text files to dataframes

right_dataframe = right_dataframe.rename(columns = {"station_code": "src_station"})

a =pd.merge(left_dataframe, right_dataframe, on="src_station", how="left")  # for identifying latitude and longitude of the corresponding stations in route, used left outer join to merge the two text files 

a.to_csv('C:\\Users\\S\\Downloads\\wimt_full_route_map_merged.txt', header=True, index=False, sep='\t', mode='w')





# plotting all the routes iterating through file of all the trains data resulting in overlapping of routes many times


file3 = open('C:\\Users\\S\\Downloads\\wimt_full_route_map_merged.txt',"r")
route_lat,route_lon = [],[]
count = 0
next(file3)
train_no = 1
for line in file3:  
    x = int(line.split('\t')[0])
    if count == 0:
        count+=1
        train_no = int(x)
        try:
            route_lat.append(float(line.split('\t')[11]))
            route_lon.append(float(line.split('\t')[12][:-1]))
        except:
            continue #only for spaces
    else:
        if x == train_no:
            try:
                route_lat.append(float(line.split('\t')[11]))
                route_lon.append(float(line.split('\t')[12][:-1]))
            except:
                continue #only for spaces
        else:
            train_no = int(x)
            gmap1.plot(route_lat, route_lon, color = 'blue', edge_width = 2)
            route_lat,route_lon = [],[]
            try:
                route_lat.append(float(line.split('\t')[11]))
                route_lon.append(float(line.split('\t')[12][:-1]))
            except:
                continue #only for spaces
    count+=1       
gmap1.plot(route_lat, route_lon, color = 'blue', edge_width = 2) 
gmap1.draw( "C:\\Users\\S\\OneDrive\\Desktop\\India_train-routes.html" )





#  optimised algo

#segregating the routes from full-route-map to prevent repetitive overlapping of the same routes again and again 
      
file3 = open('C:\\Users\\S\\Downloads\\wimt_full_route_map_merged.txt',"r")
file4 = open('C:\\Users\\S\\Downloads\\wimt_full_seperated_route_map_merged.txt',"a")
count = 0
start_dest = []
names = []
lines = ""
next(file3)
flag = 0
name = ""
train_no = 1
for line in file3:  
    x = int(line.split('\t')[0])
    prev_name = name
    name = line.split('\t')[1]
    seq = int(line.split('\t')[2])
    if count == 0:
        count+=1
        train_no = int(x)
        flag = 1
        start_dest.append([])
        start_dest[0].append(name)
        lines+= line
    else:
        if x == train_no:
            lines+= line
        else:
            train_no = int(x)
            count+=1
            if flag == 1:
                start_dest[0].append(prev_name)
                flag = 0
                file4.write(lines)
            else:
                names.append(prev_name)
                check = 0
                #print(names)
                for i in range(0,len(start_dest)):
                    start_dest[i].sort()
                    names.sort()
                    if start_dest[i] == names :
                        check = 1
                        break;      
                if check == 0:
                    start_dest.append(names)
                    file4.write(lines) 
                names = []    
            names.append(name)
            lines = ""
            lines+= line

file4.close()
print(count)
print(start_dest)


## plotting the routes using segregated file data 

file5 = open('C:\\Users\\S\\Downloads\\wimt_full_seperated_route_map_merged.txt',"r")
route_lat,route_lon = [],[]
count = 0
next(file5)
train_no = 1
for line in file5:  
    x = int(line.split('\t')[0])
    if count == 0:
        count+=1
        train_no = int(x)
        try:
            route_lat.append(float(line.split('\t')[11]))
            route_lon.append(float(line.split('\t')[12][:-1]))
        except:
            continue #only for spaces
    else:
        if x == train_no:
            try:
                route_lat.append(float(line.split('\t')[11]))
                route_lon.append(float(line.split('\t')[12][:-1]))
            except:
                continue #only for spaces
        else:
            train_no = int(x)
            gmap1.plot(route_lat, route_lon, color = 'blue', edge_width = 2)
            route_lat,route_lon = [],[]
            try:
                route_lat.append(float(line.split('\t')[11]))
                route_lon.append(float(line.split('\t')[12][:-1]))
            except:
                continue #only for spaces
    count+=1       
gmap1.plot(route_lat, route_lon, color = 'blue', edge_width = 2) 
gmap1.draw( "C:\\Users\\S\\OneDrive\\Desktop\\India_train-routes.html" )

















## applying linear regression over all routes

# breaking the route line to decrease the total error

import numpy as np 
import matplotlib.pyplot as plt
import gmplot
  
def estimate_coef(x1, y1):
    x = np.array(x1)
    y = np.array(y1)
    
    # number of points 
    n = np.size(x) 
  
    # mean of x and y array
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b1 = SS_xy / SS_xx 
    b0 = m_y - b1*m_x 
  
    return(b0, b1)  

def plot_regression_route(lat,lon,gmap1,pcolor):

    x = np.array(lat)
    # estimating coefficients 
    b = estimate_coef(lat,lon) 
    #print(b[0],b[1])
    
    # plotting regression line 
    y_pred = b[0] + b[1]*x
 
    gmap1.plot(x,y_pred,pcolor,edge_width=1)

def main():

    gmap1 = gmplot.GoogleMapPlotter(21.1458,79.0882, 5 )  
    
    file3 = open('C:\\Users\\S\\Downloads\\wimt_full_seperated_route_map_merged.txt',"r")
    route_lat,route_lon = [],[]
    count = 0

    for line in file3:  
        x = int(line.split('\t')[0])
        if count == 0:
            count+=1
            train_no = int(x)
            try:
                route_lat.append(float(line.split('\t')[11]))
                route_lon.append(float(line.split('\t')[12][:-1]))
            except:
                continue #only for spaces
        else:
            if x == train_no:
                try:
                    route_lat.append(float(line.split('\t')[11]))
                    route_lon.append(float(line.split('\t')[12][:-1]))
                except:
                    continue #only for spaces
            else:
                train_no = int(x)
                plot_regression_route(route_lat,route_lon,gmap1,"red")
                route_lat,route_lon = [],[]
                try:
                    route_lat.append(float(line.split('\t')[11]))
                    route_lon.append(float(line.split('\t')[12][:-1]))
                except:
                    continue #only for spaces
        count+=1       
    plot_regression_route(route_lat,route_lon,gmap1,"red")
    gmap1.draw( "C:\\Users\\S\\OneDrive\\Desktop\\India_train-routes1.html" )
    file3.close()
    
if __name__ == "__main__": 
    main()
    



## linear regression along with some constraints to break routes wherever necessary

# breaking the route line to decrease the total error

import numpy as np 
import matplotlib.pyplot as plt
import gmplot
  
def estimate_coef(x1, y1):
    x = np.array(x1)
    y = np.array(y1)
    
    # number of points 
    n = np.size(x) 
  
    # mean of x and y array
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b1 = SS_xy / SS_xx 
    b0 = m_y - b1*m_x 
  
    return(b0, b1)  


def plot_regression_route(lat,lon,gmap1,pcolor):

    # estimating coefficients 
    b = estimate_coef(lat,lon) 
    #print(b[0],b[1])
    
    # plotting regression line 
    y_pred = b[0] + b[1]*np.array(lat)
    
    neg = 0
    x1,y1,x2,y2=[],[],[],[]
    for i in range(len(lon)):
        if lon[i] - y_pred[i] < 0:
            neg+=1
            x1.append(lat[i])
            y1.append(lon[i])
        else:
            if neg >= 4:
                x1.append(lat[i])
                y1.append(lon[i])
                b1 = estimate_coef(x1,y1)
                y_pred1 = b1[0] + ( b1[1]* np.array(x1) )
                gmap1.plot(x1,y_pred1,pcolor,edge_width=2.5)
                x1,y1=[],[]
                neg = 0
            elif neg > 0:
                x2 = x2 + x1
                y2 = y2 + y1
                x1,y1 = [],[]
                neg = 0
                
            x2.append(lat[i])
            y2.append(lon[i])
        
    
    if neg >= 4 :
        x2.append(x1[0])
        y2.append(y1[0])
        b1 = estimate_coef(x1,y1)
        y_pred1 = b1[0] + ( b1[1]* np.array(x1) )
        gmap1.plot(x1,y_pred1,pcolor,edge_width=2.5)
    elif neg > 0 and neg < 4:
        x2 = x2 + x1
        y2 = y2 + y1
        
    b2 = estimate_coef(x2,y2)
    y_pred2 = b2[0] + ( b2[1]*np.array(x2))
    #gmap1.apikey = "AIzaSyAbr98I2YDjSiJR5Sv81zkfrB5uNAhCuMU"
    gmap1.plot(x2,y_pred2,pcolor,edge_width=2.5)
    
    

def main():

    gmap1 = gmplot.GoogleMapPlotter(21.1458,79.0882, 5 )  
    
    file3 = open('C:\\Users\\S\\Downloads\\wimt_full_seperated_route_map_merged.txt',"r")
    route_lat,route_lon = [],[]
    count = 0

    for line in file3:  
        x = int(line.split('\t')[0])
        if count == 0:
            count+=1
            train_no = int(x)
            try:
                route_lat.append(float(line.split('\t')[11]))
                route_lon.append(float(line.split('\t')[12][:-1]))
            except:
                continue #only for spaces
        else:
            if x == train_no:
                try:
                    route_lat.append(float(line.split('\t')[11]))
                    route_lon.append(float(line.split('\t')[12][:-1]))
                except:
                    continue #only for spaces
            else:
                train_no = int(x)
                plot_regression_route(route_lat,route_lon,gmap1,"red")
                route_lat,route_lon = [],[]
                try:
                    route_lat.append(float(line.split('\t')[11]))
                    route_lon.append(float(line.split('\t')[12][:-1]))
                except:
                    continue #only for spaces
        count+=1       
    plot_regression_route(route_lat,route_lon,gmap1,"red")
    gmap1.draw( "C:\\Users\\S\\OneDrive\\Desktop\\India_train-routes2.html" )
    file3.close()
    
if __name__ == "__main__": 
    main()







# breaking the route line to decrease the total error and improvised plot_regression_route function to include the last point of one line to another line as first point ( for a better view of a route)

import numpy as np 
import matplotlib.pyplot as plt
import gmplot
  
def estimate_coef(x1, y1):
    x = np.array(x1)
    y = np.array(y1)
    
    # number of points 
    n = np.size(x) 
  
    # mean of x and y array
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b1 = SS_xy / SS_xx 
    b0 = m_y - b1*m_x 
  
    return(b0, b1)  


def plot_regression_route(lat,lon,gmap1,pcolor,name):

    # estimating coefficients 
    b = estimate_coef(lat,lon) 
    #print(b[0],b[1])
    
    # plotting regression line 
    y_pred = b[0] + b[1]*np.array(lat)
    
    neg = 0
    x1,y1,x2,y2=[],[],[],[]
    for i in range(len(lon)):
        if lon[i] - y_pred[i] < 0:
            neg+=1
            x1.append(lat[i])
            y1.append(lon[i])
        else:
            if neg >= 4:
                x1.append(lat[i])
                y1.append(lon[i])
                b1 = estimate_coef(x1,y1)
                y_pred1 = b1[0] + ( b1[1]* np.array(x1) )
                gmap1.plot(x1,y_pred1,pcolor,edge_width=2.5)
                x1,y1=[],[]
                neg = 0
            elif neg > 0:
                x2 = x2 + x1
                y2 = y2 + y1
                x1,y1 = [],[]
                neg = 0
                
            x2.append(lat[i])
            y2.append(lon[i])
        print(name[i],(lon[i]-y_pred[i]))
    
    if neg >= 4 :
        x2.append(x1[0])
        y2.append(y1[0])
        b1 = estimate_coef(x1,y1)
        y_pred1 = b1[0] + ( b1[1]* np.array(x1) )
        gmap1.plot(x1,y_pred1,pcolor,edge_width=2.5)
    elif neg > 0 and neg < 4:
        x2 = x2 + x1
        y2 = y2 + y1
        
    b2 = estimate_coef(x2,y2)
    y_pred2 = b2[0] + ( b2[1]*np.array(x2))
    #gmap1.apikey = "AIzaSyAbr98I2YDjSiJR5Sv81zkfrB5uNAhCuMU"
    gmap1.plot(x2,y_pred2,pcolor,edge_width=2.5)
    

def main():

    gmap1 = gmplot.GoogleMapPlotter(18.77778,73.31833, 10 ) 
    
    file3 = open('C:\\Users\\S\\OneDrive\\Desktop\\local_train_route_coord.txt',"r")
    route_lat,route_lon,name = [],[],[]
    count = 0
    for line in file3:
        if count == 0:
            count+=1
            continue;  
        color = line.split('\t')[12]
        if color == "blue":
            try:
                route_lat.append(float(line.split('\t')[10]))
                route_lon.append(float(line.split('\t')[11][:-1]))
                name.append((line.split('\t')[9]))
            except:
                continue #only for spaces
        count+=1  
    gmap1.scatter(route_lat,route_lon,'white',size = 100, marker = False)
    plot_regression_route(route_lat,route_lon,gmap1,"blue",name)
    gmap1.draw( "C:\\Users\\S\\OneDrive\\Desktop\\LR(improved).html")
    
if __name__ == "__main__": 
    main()
