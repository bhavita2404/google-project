# %%
 class Graph:
        # Graph Constructor 
        def __init__(self, v, e): 
            self.v = v 
            self.e = e 
            
 # Function to add an edge in an undirected graph 
    def add_edge(self, src, dest): 
        # Adding the node to the source node 
        node = AdjNode(dest) 
        node.next = self.graph[src] 
        self.graph[src] = node 
  
        # Adding the source node to the destination as 
        # it is the undirected graph 
        node = AdjNode(src) 
        node.next = self.graph[dest] 
        self.graph[dest] = node       
 
    
def createGraph(data, file):
    )
    
    #create adjacency list
    
    G = Graph(v, e) 
  
    # /* 0-----1 
    # | \ | 
    # | \ | 
    # | \ | 
    # 2-----3 */ 
  
    # direction from 0 
    G.diri[0][1] = 1
    G.diri[0][2] = 1
    G.diri[0][3] = 1
  
    # direction from 1 
    G.diri[1][0] = 1
    G.diri[1][3] = 1
  
    # direction from 2 
    G.diri[2][0] = 1
    G.diri[2][3] = 1
  
    # direction from 3 
    G.diri[3][0] = 1
    G.diri[3][1] = 1
    G.diri[3][2] = 1
  
    return G 
  
 def findDegree(G, ver): 
    degree = 0
    for i in range(G.v): 
        if G.diri[ver][i] == 1: 
            degree += 1
    return degree 

 if __name__ == "__main__": 
  
    data = pd.read_csv('C:\\Users\\S\\Downloads\\station_info_aggregated.txt', sep='|')
  
    file = open('C:\\Users\\S\\Downloads\\wimt_full_seperated_route_map_merged.txt',"r")
    # Creating a Graph 
    G = createGraph(data,file) 
    file.close()
    ver = 0
  
    # Function calling 
    degree = findDegree(G, ver) 
    print(degree)
    
    # to find a degree in adjacency list just find the length of the list of the corresponding node

# %%
import pandas as pd

# %%
  
# A class to represent the adjacency list of the node 
class AdjNode: 
    def __init__(self, data): 
        self.vertex = data
        self.next = None
  
  
# A class to represent a graph. A graph 
# is the list of the adjacency lists. 
# Size of the array will be the no. of the 
# vertices "V" 
class Graph: 
    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [None] * self.V 
  
    # Function to add an edge in an undirected graph 
    def add_edge(self, src, dest): 
        # Adding the node to the source node 
        node = AdjNode(dest) 
        node.next = self.graph[src] 
        self.graph[src] = node 
  
        # Adding the source node to the destination as 
        # it is the undirected graph 
        node = AdjNode(src) 
        node.next = self.graph[dest] 
        self.graph[dest] = node 
  
    # Function to print the graph 
    def print_graph(self): 
        for i in range(self.V): 
            print("Adjacency list of vertex {}\n head".format(i), end="") 
            temp = self.graph[i] 
            while temp: 
                print(" -> {}".format(temp.vertex), end="") 
                temp = temp.next
            print(" \n") 
  
    #def findDegree(G, ver): 
    #degree = 0
    #for i in range(G.v): 
        #if G.diri[ver][i] == 1: 
            #degree += 1
    #return degree
# Driver program to the above graph class 
if __name__ == "__main__": 
    
    data = pd.read_csv('C:\\Users\\S\\Downloads\\station_info_aggregated.txt', sep='|')
    vertices = data['station_code'].tolist()
    v = len(vertices)
    
    graph = Graph(v)
    
    graph.add_egde(0,2)
    graph.print_graph()    
    
    
    file.close()
    ver = 0
  
    # Function calling 
    #degree = findDegree(G, ver) 
    #print(degree)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1df08d93b4f0> in <module>
#      53     graph = Graph(v)
#      54
# ---> 55     graph.add_egde(0,2)
#      56     graph.print_graph()
#      57
#
# AttributeError: 'Graph' object has no attribute 'add_egde'

# %%
file = open('C:\\Users\\S\\Downloads\\wimt_full_seperated_route_map_merged.txt',"r")
count = 0
    next(file)
    train_no = 1
    name, prev_n = "",""
    for line in file:  
        x = int(line.split('\t')[0])
        prev_n = name
        name = line.split('\t')[1]
        if count == 0:
            count+=1
            train_no = int(x)
        else:
            if x == train_no:
                graph.add_egde(name,prev_n)
            else:
                train_no = int(x)
        count+=1

# %%
""" 
A Python program to demonstrate the adjacency 
list representation of the graph 
"""
  
# A class to represent the adjacency list of the node 
class AdjNode: 
    def __init__(self, data): 
        self.vertex = str(data) 
        self.next = None
  
  
# A class to represent a graph. A graph 
# is the list of the adjacency lists. 
# Size of the array will be the no. of the 
# vertices "V" 
class Graph: 
    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [None] * self.V 
  
    # Function to add an edge in an undirected graph 
    def add_edge(self, src, dest): 
        # Adding the node to the source node 
        node = AdjNode(dest) 
        node.next = self.graph[src] 
        self.graph[src] = node 
  
        # Adding the source node to the destination as 
        # it is the undirected graph 
        node = AdjNode(src) 
        node.next = self.graph[dest] 
        self.graph[dest] = node 
  
    # Function to print the graph 
    def print_graph(self): 
        for i in range(self.V): 
            print("Adjacency list of vertex {}\n head".format(i), end="") 
            temp = self.graph[i] 
            while temp: 
                print(" -> {}".format(temp.vertex), end="") 
                temp = temp.next
            print(" \n") 
  
  
# Driver program to the above graph class 
if __name__ == "__main__": 
    V = 5
    graph = Graph(V) 
    graph.add_edge('str', 'dfg') 
    graph.add_edge('str', 'tgf') 
    
  
    graph.print_graph() 
  
# This code is contributed by Kanav Malhotra
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-00cfbe9c06ca> in <module>
#      48     V = 5
#      49     graph = Graph(V)
# ---> 50     graph.add_edge('str', 'dfg')
#      51     graph.add_edge('str', 'tgf')
#      52
#
# <ipython-input-13-00cfbe9c06ca> in add_edge(self, src, dest)
#      24         # Adding the node to the source node
#      25         node = AdjNode(dest)
# ---> 26         node.next = self.graph[str(src)]
#      27         self.graph[src] = node
#      28
#
# TypeError: list indices must be integers or slices, not str
